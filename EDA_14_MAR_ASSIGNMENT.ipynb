# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import warnings
warnings.filterwarnings('ignore')

plt.style.use('fivethirtyeight')
# %matplotlib inline

pd.set_option('display.max_columns',30)

# %%
df = pd.read_csv("/content/heart_failure_clinical_records_dataset.csv")

# %%
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
df.tail()
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 294                    1   155000.0               1.1           143    1
# 295                    0   270000.0               1.2           139    0
# 296                    0   742000.0               0.8           138    0
# 297                    0   140000.0               1.4           140    1
# 298                    0   395000.0               1.6           136    1
#
#      smoking  time  DEATH_EVENT
# 294        1   270            0
# ...

# %%
# what is the distribution of age among heart failure patients in the datasets?

# %%
df['age'].unique()
# Out:
# array([75.   , 55.   , 65.   , 50.   , 90.   , 60.   , 80.   , 62.   ,
#        45.   , 49.   , 82.   , 87.   , 70.   , 48.   , 68.   , 53.   ,
#        95.   , 58.   , 94.   , 85.   , 69.   , 72.   , 51.   , 57.   ,
#        42.   , 41.   , 67.   , 79.   , 59.   , 44.   , 63.   , 86.   ,
#        66.   , 43.   , 46.   , 61.   , 81.   , 52.   , 64.   , 40.   ,
#        60.667, 73.   , 77.   , 78.   , 54.   , 47.   , 56.   ])

# %%
len(df['age'].unique())
# Out:
# 47

# %%
df['age'].nunique()
# Out:
# 47

# %%
df["age"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 294    False
# 295    False
# 296    False
# 297    False
# 298    False
# Name: age, Length: 299, dtype: bool

# %%
df["age"].dropna(inplace = True)

# %%
df.dtypes
# Out:
# age                         float64
# anaemia                       int64
# creatinine_phosphokinase      int64
# diabetes                      int64
# ejection_fraction             int64
# high_blood_pressure           int64
# platelets                   float64
# serum_creatinine            float64
# serum_sodium                  int64
# sex                           int64
# smoking                       int64
# time                          int64
# DEATH_EVENT                   int64
# dtype: object

# %%
df["sex"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 294    1
# 295    0
# 296    0
# 297    1
# 298    1
# Name: sex, Length: 299, dtype: int64

# %%
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
df['DEATH_EVENT'].unique()
# Out:
# array([1, 0])

# %%
df[df['DEATH_EVENT'] == 1]
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 220  73.0        0                       582         0                 20
# 230  60.0        0                       166         0                 30
# 246  55.0        0                      2017         0                 25
# 262  65.0        1                       258         1                 25
# 266  55.0        0                      1199         0                 20
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
df["DEATH_EVENT"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 294    0
# 295    0
# 296    0
# 297    0
# 298    0
# Name: DEATH_EVENT, Length: 299, dtype: int64

# %%
df["DEATH_EVENT"].unique()
# Out:
# array([1, 0])

# %%
df["DEATH_EVENT"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 294    0
# 295    0
# 296    0
# 297    0
# 298    0
# Name: DEATH_EVENT, Length: 299, dtype: int64

# %%
df['age'].dropna()
# Out:
# 0      75.0
# 1      55.0
# 2      65.0
# 3      50.0
# 4      65.0
#        ...
# 294    62.0
# 295    55.0
# 296    45.0
# 297    45.0
# 298    50.0
# Name: age, Length: 299, dtype: float64

# %%
df["DEATH_EVENT"].dropna()
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 294    0
# 295    0
# 296    0
# 297    0
# 298    0
# Name: DEATH_EVENT, Length: 299, dtype: int64

# %%
#univariate analysis
#Q-1 what is the distribution of age among heart failure patients in the datasets

plt.figure(figsize = (10, 6))
sns.histplot(x =df["DEATH_EVENT"],y = df["age"] , kde = True, color = 'green')
plt.title('Distribution of age')
plt.xlabel('death_event')
plt.ylabel('age')
plt.show()

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
#Q-2 how does the death rate vary with age?
plt.figure(figsize = (10,3))
sns.swarmplot(x = df['DEATH_EVENT'],y = df['age'],hue = df['sex'],color = "red",edgecolor = 'black')
plt.show()

# %%
df["sex"] = df["sex"].replace(to_replace = {0: "female",1:"male"})

# %%
df["sex"]
# Out:
# 0        male
# 1        male
# 2        male
# 3        male
# 4      female
#         ...
# 294      male
# 295    female
# 296    female
# 297      male
# 298      male
# Name: sex, Length: 299, dtype: object

# %%
#Q-3 what is the percentage of male and female patients in the dataset?
df["sex"].value_counts(normalize = True)
# insights:---> male=64%, female = 35
# Out:
# sex
# male      0.648829
# female    0.351171
# Name: proportion, dtype: float64

# %%
plt.figure(figsize = (10,4))
sns.violinplot(data = df,x  = "sex",color = "orange")
# Out:
# <Axes: xlabel='sex'>

# %%
len(df[df["sex"] == 'male'])
# Out:
# 194

# %%
len(df)-len(df[df["sex"] == 'male'])
# Out:
# 105

# %%
#Q-4 how does the platelet count vary among different age group?
plt.figure(figsize = (10,3))
sns.catplot(data = df, x='platelets',y = 'age',color = "maroon")
plt.show()
#insights :--> there are lots of platelets count downfall in the above 70 age people

# %%
df["platelets"].unique()
# Out:
# array([265000.  , 263358.03, 162000.  , 210000.  , 327000.  , 204000.  ,
#        127000.  , 454000.  , 388000.  , 368000.  , 253000.  , 136000.  ,
#        276000.  , 427000.  ,  47000.  , 262000.  , 166000.  , 237000.  ,
#         87000.  , 297000.  , 289000.  , 149000.  , 196000.  , 284000.  ,
#        153000.  , 200000.  , 360000.  , 319000.  , 302000.  , 188000.  ,
#        228000.  , 226000.  , 321000.  , 305000.  , 329000.  , 185000.  ,
#        218000.  , 194000.  , 310000.  , 271000.  , 451000.  , 140000.  ,
#        395000.  , 418000.  , 351000.  , 255000.  , 461000.  , 223000.  ,
#        216000.  , 254000.  , 390000.  , 385000.  , 119000.  , 213000.  ,
#        274000.  , 244000.  , 497000.  , 374000.  , 122000.  , 243000.  ,
#        266000.  , 317000.  , 283000.  , 324000.  , 293000.  , 172000.  ,
#        406000.  , 173000.  , 304000.  , 235000.  , 181000.  , 249000.  ,
#        219000.  , 318000.  , 221000.  , 298000.  , 286000.  , 621000.  ,
# ...

# %%
#Q-5 is there a correlation between creatinine and sodium levels in the blood?

sns.lineplot(data=df, x="creatinine_phosphokinase", y="serum_sodium",color = "pink")
# nearly all the sodium are present at the level of creatinine between 0 to 1000
# Out:
# <Axes: xlabel='creatinine_phosphokinase', ylabel='serum_sodium'>

# %%
df["creatinine_phosphokinase"].value_counts()
# Out:
# creatinine_phosphokinase
# 582     47
# 66       4
# 129      4
# 231      3
# 69       3
#         ..
# 748      1
# 1876     1
# 936      1
# 292      1
# 2413     1
# Name: count, Length: 208, dtype: int64

# %%
df["serum_sodium"].value_counts()
# Out:
# serum_sodium
# 136    40
# 137    38
# 140    35
# 134    32
# 138    23
# 139    22
# 135    16
# 132    14
# 141    12
# 142    11
# 133    10
# 145     9
# 130     9
# 144     5
# 131     5
# 127     3
# 143     3
# 128     2
# 129     2
# 121     1
# 116     1
# 146     1
# 126     1
# 124     1
# 113     1
# 125     1
# 148     1
# Name: count, dtype: int64

# %%
df["serum_sodium"].unique()
# Out:
# array([130, 136, 129, 137, 116, 132, 131, 138, 133, 140, 127, 121, 135,
#        134, 144, 128, 145, 142, 139, 146, 141, 143, 126, 124, 113, 125,
#        148])

# %%
# Q6 how does the prevalence of high blood pressure differ between male and female patients
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
plt.figure(figsize = (10,6))
sns.kdeplot(data = df,x = "high_blood_pressure",hue = "sex")
plt.show()
# males are more used to the disease of high blood pressure

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
df.smoking,df.DEATH_EVENT
# Out:
# (0      0
#  1      0
#  2      1
#  3      0
#  4      0
#        ..
#  294    1
#  295    0
#  296    0
#  297    1
#  298    1
#  Name: smoking, Length: 299, dtype: int64,
#  0      1
#  1      1
#  2      1
#  3      1
#  4      1
#        ..
#  294    0
#  295    0
#  296    0
#  297    0
#  298    0
#  Name: DEATH_EVENT, Length: 299, dtype: int64)

# %%
#Q7 what is the relation betwween smoking habits and the occurence of heart failure?
plt.figure(figsize = (10,4))
sns.catplot(
    data=df, x="smoking", y="DEATH_EVENT", #col="sex",
    kind="bar", height=4, aspect=.6,
)
# relation:--> there is the slight difference between guys who have smoking habits and has occurence.statistically guys having no smoking habits are probably the risk slighter more than the guys have smoking habits

# %%
df.DEATH_EVENT
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 294    0
# 295    0
# 296    0
# 297    0
# 298    0
# Name: DEATH_EVENT, Length: 299, dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
df.age.unique()
# Out:
# array([75.   , 55.   , 65.   , 50.   , 90.   , 60.   , 80.   , 62.   ,
#        45.   , 49.   , 82.   , 87.   , 70.   , 48.   , 68.   , 53.   ,
#        95.   , 58.   , 94.   , 85.   , 69.   , 72.   , 51.   , 57.   ,
#        42.   , 41.   , 67.   , 79.   , 59.   , 44.   , 63.   , 86.   ,
#        66.   , 43.   , 46.   , 61.   , 81.   , 52.   , 64.   , 40.   ,
#        60.667, 73.   , 77.   , 78.   , 54.   , 47.   , 56.   ])

# %%
# Q-8are there any noticable patterns in the distribution of death events across different age groups?
plt.figure(figsize = (10,5))
sns.displot(data=df,x="DEATH_EVENT", y = "age")
plt.show()
# pattern:--> there are clear stats that guys having age between 50 to 70 are lesser death event than other. and most of the people either having death event or not are between the age of 40 to 100

# %%
len(df[df["DEATH_EVENT"] == 1])
# Out:
# 96

# %%
len(df[(df["DEATH_EVENT"] == 1) & (df["age"] > 50) & (df["age"]<70)])
# Out:
# 39

# %%
#Q-9 Is there any significance difference in ejection fraction between patients with and without diabetes?
sns.barplot(data = df,x = "ejection_fraction",y = "diabetes")
# significance difference:--> there is a huge relationship between the ejection fraction and diabetic patients.those who have more ejection fraction are surely suffering from diabetes.
# and those who are low ejection fraction having less diabetic and even not also
# Out:
# <Axes: xlabel='ejection_fraction', ylabel='diabetes'>

# %%
df.ejection_fraction,df.diabetes
# Out:
# (0      20
#  1      38
#  2      20
#  3      20
#  4      20
#         ..
#  294    38
#  295    38
#  296    60
#  297    38
#  298    45
#  Name: ejection_fraction, Length: 299, dtype: int64,
#  0      0
#  1      0
#  2      0
#  3      0
#  4      1
#        ..
#  294    1
#  295    0
#  296    1
#  297    0
#  298    0
#  Name: diabetes, Length: 299, dtype: int64)

# %%
# Q-10 how does the serum cretinine level vary between patients who survived and those who did not?

# %%
sns.boxplot(data = df,x ='creatinine_phosphokinase',hue = "DEATH_EVENT" )
# much high creatinine level harms the life causing death
# Out:
# <Axes: xlabel='creatinine_phosphokinase'>
